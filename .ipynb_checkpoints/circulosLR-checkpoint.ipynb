# %% [markdown]
# # Regresion Logaritmica

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Parametros de las circunferencias
x0 = 4
y0 = 4
r0 = 2

x1 = 4
y1 = 4
r1 = 4

# Coordenadas polares aleatorias de ambas areas
ang = np.arange(0, 2*np.pi, 0.05)    # Puntos de una circunferencia en paso 0.05 rad

ptos_A1 = np.random.rand(ang.shape[0])*r0   # Puntos de la circunferencia 1
ptos_A2 = (np.random.rand(ang.shape[0])+1)*r1   # Puntos de la circunferencia 2

# Pasamos a coordenadas cartesianas los puntos aleatorios
x_int = ptos_A1*np.cos(ang) + x0
y_int = ptos_A1*np.sin(ang) + y0

x_ext = ptos_A2*np.cos(ang) + x1
y_ext = ptos_A2*np.sin(ang) + y1

# %%
plt.plot(x_int, y_int, 'x')
plt.plot(x_ext, y_ext, 'o')

# %%
ang.shape[0]
# Out:
# 126

# %%
z_int = np.ones((ang.shape[0],))
z_ext = np.zeros((ang.shape[0],))

# %% [markdown]
# Para la funcion z se puede tomar lo siguiente:
# receordando que la ecuacion de una cia es:
#     Ay^2 + Bx^2 + Cy + Dx + E = 0
#     esto se puede considerar como
#     theta4 * x4 + theta3 * x3 + theta2 * x2 + theta1 * x1 + theta0 * x0
# Entonces nuestro vector es:
# theta = [theta0 theta1 theta2 theta3 theta4]
# x = [1 x1 x2 x3 x4]

# %%
B = np.ones((ang.shape[0]*2,))
x = np.concatenate((x_int,x_ext),axis=0)
y = np.concatenate((y_int,y_ext),axis=0)
x_square = x**2
y_square = y**2
Z = np.concatenate((z_int,z_ext),axis=0)
print(z.shape)
X = np.vstack((B,x,y,x_square,y_square)).T
X.shape
# Out:
# (252,)
# (252, 5)

# %%
Y = Z.T
Y
print(Y.shape)
# Out:
# (252,)

# %%
theta = np.array(np.random.rand(5,))
theta
print(Z.shape, X.shape, theta.shape)
# Out:
# (252,) (252, 5) (5,)

# %%
def sigmoide(z):
    return 1./(1+np.exp(-z)) #la z es de 252x1

# %%
max_iter = 1000
m = (X.shape[0])
#print(m)
alpha = 0.01
theta = np.array(np.random.rand(5,))
J = []
for iter in range(max_iter):
    Z = np.dot(theta, np.transpose(X))
    #Z = np.dot(X, theta)
    #print(Z)
    h = sigmoide(Z)
    #print(h)
    #J = np.sum((Y - h)**2) / (2*m)
    J.append(1/m * np.dot(-Y,np.log(h+0.00000001)) - np.dot((1-Y),(np.log(1-h+0.00000001))))
    dj = -(h-y).dot(X)/m
    #print(dj)
    #print(np.sum(np.dot((y_data - h),x)))
    theta -= alpha * dj
# Out:
# C:\Users\josec\AppData\Local\Temp\ipykernel_24424\2890266917.py:2: RuntimeWarning: overflow encountered in exp
#   return 1./(1+np.exp(-z)) #la z es de 252x1

# %%
theta
# Out:
# array([  30.45031861,  116.94601298,  213.50367396,  748.7195434 ,
#        1476.25035929])

# %%
def pred(x,y):
    Z = x.dot(theta)
    h = sigmoide(z)
    return h

# %%
print(X.shape)
# Out:
# (252, 5)

# %%
plt.plot(J)
print(J[-1])
#y_est = np.dot(theta, np.transpose(X))
est = pred(X,Y)
# Out:
# 9.210339111976198
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[129], line 4
#       2 print(J[-1])
#       3 #y_est = np.dot(theta, np.transpose(X))
# ----> 4 est = pred(X,Y)
#
# Cell In[95], line 2, in pred(x, y)
#       1 def pred(x,y):
# ----> 2     Z = x.dot(theta)
#       3     h = sigmoide(z)
#       4     return h
#
# ValueError: shapes (50,50) and (5,) not aligned: 50 (dim 1) != 5 (dim 0)

# %%
est = pred(X,Y)

plt.plot(x_int, y_int, 'x')
plt.plot(x_ext, y_ext, 'o')
plt.xlabel(f"theta: {theta}")
# create the figure

#plt.plot(x,y)
plt.show()

# %%
plt.plot(est)

# %%
x = np.linspace(1, 7, 50)
y = np.linspace(-3, 12,50)
X,Y = np.meshgrid(x,y)
F = theta[4]*Y**2 + theta[3]*X**2 + theta[2] * Y + theta[1] * X + theta[0]
fig,ax = plt.subplots()
print(F)
ax.contour(X,Y,F)
# Out:
# [[ -15986.58976331  -16265.29135382  -16573.94422161 ...  -61462.89526056
#    -63149.30688339  -64865.6697835 ]
#  [ -13052.22617381  -13330.92776431  -13639.58063211 ...  -58528.53167105
#    -60214.94329388  -61931.30619399]
#  [ -10441.71331171  -10720.41490222  -11029.06777001 ...  -55918.01880896
#    -57604.43043179  -59320.7933319 ]
#  ...
#  [-228154.13738927 -228432.83897978 -228741.49184757 ... -273630.44288652
#   -275316.85450935 -277033.21740946]
#  [-240440.75798815 -240719.45957866 -241028.11244645 ... -285917.06348539
#   -287603.47510822 -289319.83800833]
#  [-253051.22931443 -253329.93090494 -253638.58377273 ... -298527.53481168
#   -300213.94643451 -301930.30933462]]
