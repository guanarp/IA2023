# %%
import pandas as pd

# %%
path = 'pmsm_temperature_data.csv'

# %%
df = pd.read_csv(path, sep='\,')
df.head()
# Out:
# C:\Users\josec\AppData\Local\Temp\ipykernel_30972\3398251063.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(path, sep='\,')
#        "ambient   coolant       u_d       u_q  motor_speed    torque  \
# 0  "-0.75214297 -1.118446  0.327935 -1.297858    -1.222428 -0.250182
# 1  "-0.77126324 -1.117021  0.329665 -1.297686    -1.222429 -0.249133
# 2  "-0.78289163 -1.116681  0.332771 -1.301822    -1.222428 -0.249431
# 3  "-0.78093535 -1.116764  0.333700 -1.301852    -1.222430 -0.248636
# 4   "-0.7740426 -1.116775  0.335206 -1.303118    -1.222429 -0.248701
#
#         i_d       i_q        pm  stator_yoke  stator_tooth  stator_winding  \
# 0  1.029572 -0.245860 -2.522071    -1.831422     -2.066143       -2.018033
# 1  1.029509 -0.245832 -2.522418    -1.830969     -2.064859       -2.017631
# 2  1.029448 -0.245818 -2.522673    -1.830400     -2.064073       -2.017343
# 3  1.032845 -0.246955 -2.521639    -1.830333     -2.063137       -2.017632
# 4  1.031807 -0.246610 -2.521900    -1.830498     -2.062795       -2.018145
#
#   profile_id"
# 0          4"
# 1          4"
# 2          4"
# 3          4"
# 4          4"

# %%
df.columns = df.columns.str.replace('\"',"")
df.iloc[:,0] = df.iloc[:,0].str.replace('\"',"")
df.iloc[:,-1] = df.iloc[:,-1].str.replace('\"',"")
df.head()
# Out:
#        ambient   coolant       u_d       u_q  motor_speed    torque       i_d  \
# 0  -0.75214297 -1.118446  0.327935 -1.297858    -1.222428 -0.250182  1.029572
# 1  -0.77126324 -1.117021  0.329665 -1.297686    -1.222429 -0.249133  1.029509
# 2  -0.78289163 -1.116681  0.332771 -1.301822    -1.222428 -0.249431  1.029448
# 3  -0.78093535 -1.116764  0.333700 -1.301852    -1.222430 -0.248636  1.032845
# 4   -0.7740426 -1.116775  0.335206 -1.303118    -1.222429 -0.248701  1.031807
#
#         i_q        pm  stator_yoke  stator_tooth  stator_winding profile_id
# 0 -0.245860 -2.522071    -1.831422     -2.066143       -2.018033          4
# 1 -0.245832 -2.522418    -1.830969     -2.064859       -2.017631          4
# 2 -0.245818 -2.522673    -1.830400     -2.064073       -2.017343          4
# 3 -0.246955 -2.521639    -1.830333     -2.063137       -2.017632          4
# 4 -0.246610 -2.521900    -1.830498     -2.062795       -2.018145          4
