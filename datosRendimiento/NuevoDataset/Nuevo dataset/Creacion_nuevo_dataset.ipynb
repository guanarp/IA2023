# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import integrate
from scipy import signal
import seaborn as sns
from matplotlib.ticker import StrMethodFormatter
from scipy import integrate
SMALL_SIZE = 16
MEDIUM_SIZE = 18
BIGGER_SIZE = 20

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
datosConcatenados=pd.read_csv("Filtrado_final.csv",sep=",",index_col=False)
datosConcatenados.head()
# Out:
#    id_anony  Anho  Ciclo  Cod.Asign  Asignatura  Asignatura Codificada  \
# 0         0  2012      1       2402  COMBUSTION                     49
# 1         1  2012      1       2402  COMBUSTION                     49
# 2         2  2012      1       2402  COMBUSTION                     49
# 3         3  2012      1       2402  COMBUSTION                     49
# 4         4  2012      1       2402  COMBUSTION                     49
#
#    Semestre Cod.Car.Sec  Cod.Car.Sec Codificado  Anho.Firma  ...  Taller  \
# 0         1  INT9MECANI                      20           0  ...       0
# 1         1  MEC9-OPT                        33        2012  ...       8
# 2         1  INT9MECANI                      20        2012  ...       9
# 3         1  MEC9-OPT                        33        2012  ...       8
# 4         1  MEC9-OPT                        33           0  ...       8
#
#    Asistencia  4P_60  1R  2R  1F  2F  3F  Nota_Final  Aprobado
# ...

# %%
datosConcatenados.shape
# Out:
# (221921, 25)

# %%
caracteristicas=['id_anony']
Historico=pd.DataFrame(columns=caracteristicas)
Historico.head()
#para un estudiante
registro=pd.DataFrame(columns=caracteristicas)
registro.loc[0] =0

# %%
materias=['CALCULO 1','CALCULO 2','CALCULO 3']

Idlists=[2838, 3669, 4166]

# %%
i=-1
for estudiante in Idlists:
    i=i+1
    print(estudiante)
    #Aqui se almacena todos los datos disponibles de datosConcatenados de los alumnos que pertenecen a la lista Idlists
    datosEstudiante=datosConcatenados[datosConcatenados['id_anony']==estudiante]
    #Aqui se obtienen TODAS las materias que cursan este conjunto de alumnos
    #materias=np.unique(datosEstudiante.Asignatura.values)
    
    registro['id_anony']=estudiante
              
    k=0
    for materia in materias:
        k=k+1
        print(materia)
        #Aqui se almacena todas las ocasiones en la que el estudiante curso la materia
        EstudianteMateria=datosEstudiante[datosEstudiante['Asignatura']==materia]
        
        
        #ordenar por año y ciclo colocando primero la ultima vez que curso
        EstudianteMateria=EstudianteMateria.sort_values(['Anho', 'Ciclo'],ascending=(False,False))
        
        for index, row in  EstudianteMateria.iterrows():
        #if(True):
              #ultima cursada
              registro['Materia_'+str(k)]=row['Asignatura']
              registro['Anho_F_'+str(k)]=row['Anho']
              registro['ciclo_F_'+str(k)]=row['Ciclo']
              registro['NotaFinal_'+str(k)]=row['Nota_Final']
              registro['P1_F_'+str(k)]=row['1P']
              registro['P2_F_'+str(k)]=row['2P']
              registro['T_F_'+str(k)]=row['Taller']
              
              #aux=[row['id_anony'],row['Asignatura'],row['Anho'],row['Ciclo'],row['Nota_Final'],row['1P'],row['2P'],row['Taller'],0]
              
              #Historico.append(aux)
              #Historico['P1']=row
              #Historico['P2']=row
              #Historico['Taller']=row
        
        registro['NroCursadas']=len(EstudianteMateria)
        #Historico['VecesFirma']=len(registros)
        #Historico['VecesFirma']=len(registros)
    Historico=pd.concat([Historico, registro], axis=0)
# Out:
# 2838
# CALCULO 1
# CALCULO 2
# CALCULO 3
# 3669
# CALCULO 1
# CALCULO 2
# CALCULO 3
# 4166
# CALCULO 1
# CALCULO 2
# CALCULO 3

# %%
Historico
# Out:
#   id_anony  Materia_1  Anho_F_1  ciclo_F_1  NotaFinal_1  P1_F_1  P2_F_1  \
# 0     2838  CALCULO 1    2012.0        2.0          0.0    18.0     6.0
# 0     3669  CALCULO 1    2014.0        2.0          5.0    21.0    27.0
# 0     4166  CALCULO 1    2015.0        2.0          4.0    17.0    25.0
#
#    T_F_1  NroCursadas  Materia_2  ...  P1_F_2  P2_F_2  T_F_2  Materia_3  \
# 0    3.0          3.0  CALCULO 2  ...    11.0    16.0    8.0  CALCULO 3
# 0   10.0          1.0  CALCULO 2  ...    22.0    20.0    9.0  CALCULO 3
# 0   10.0          1.0  CALCULO 2  ...    16.0     0.0    7.0  CALCULO 3
#
#    Anho_F_3  ciclo_F_3 NotaFinal_3  P1_F_3  P2_F_3  T_F_3
# 0    2014.0        2.0         0.0     1.0     0.0    1.0
# 0    2015.0        2.0         4.0    13.0    30.0    7.0
# 0    2016.0        2.0         3.0     8.0     7.0    7.0
#
# [3 rows x 23 columns]
